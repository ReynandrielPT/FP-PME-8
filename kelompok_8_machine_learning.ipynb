# %% [markdown]
# <a href="https://colab.research.google.com/github/ReynandrielPT/FP-PME-8/blob/main/kelompok_8_machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.15.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.1.2)
# Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.9 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.8

# %%
import warnings
warnings.filterwarnings('ignore')
import logging, os
logging.getLogger('lightgbm').setLevel(logging.ERROR)

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from imblearn.over_sampling import RandomOverSampler, SMOTE

BALANCERS = {'None': None, 'ROS': RandomOverSampler(random_state=40), 'SMOTE': SMOTE(random_state=40)}
MODELS = {
    'Decision Tree': DecisionTreeClassifier(random_state=40),
    'Random Forest': RandomForestClassifier(random_state=40),
    'KNN': KNeighborsClassifier(),
    'Logistic Regression': LogisticRegression(max_iter=300, random_state=40),
    'Gaussian NB': GaussianNB(),
    'SVM': SVC(probability=True, random_state=40),
    'ANN': MLPClassifier(max_iter=300, random_state=40),
    'CatBoost': CatBoostClassifier(verbose=0, random_state=40),
    'XGBoost': XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', verbosity=0, random_state=40),
    'LightGBM': LGBMClassifier(random_state=40, verbose=-1)
}


plots_dir = 'plots'
results_dir = 'results'
os.makedirs(plots_dir, exist_ok=True)
os.makedirs(results_dir, exist_ok=True)

df = pd.read_csv('enhanced_anxiety_dataset.csv')
df['Stress_Level_numeric'] = df['Stress Level (1-10)']
stress_col = 'Stress_Level_numeric'

df.rename(columns={'Anxiety Level (1-10)': 'Anxiety_Level'}, inplace=True)
df['Anxiety_Category'] = df['Anxiety_Level'].apply(
    lambda x: 'Very Low' if x<=2 else 'Low' if x<=4 else 'Medium' if x<=6 else 'High' if x<=8 else 'Very High'
)
target_le = LabelEncoder()
y = target_le.fit_transform(df['Anxiety_Category'])

# ----- EDA -----
print(df.head())
print(df.describe(include='all'))
df.head().to_csv(os.path.join(results_dir, 'eda_head.csv'), index=False)
df.describe(include='all').to_csv(os.path.join(results_dir, 'eda_describe.csv'))

# ----- Preprocessing -----
base_cols = ['Age','Gender','Occupation','Sleep Hours','Physical Activity (hrs/week)',
             'Caffeine Intake (mg/day)','Alcohol Consumption (drinks/week)','Smoking',
             'Family History of Anxiety','Heart Rate (bpm)','Breathing Rate (breaths/min)',
             'Sweating Level (1-5)','Dizziness','Medication','Therapy Sessions (per month)',
             'Recent Major Life Event','Diet Quality (1-10)', stress_col]
X = df[base_cols].copy()
for col in base_cols:
    if X[col].dtype in [np.int64, np.float64]: X[col].fillna(X[col].mean(), inplace=True)
    else: X[col].fillna(X[col].mode()[0], inplace=True)
    if X[col].dtype == object: X[col] = LabelEncoder().fit_transform(X[col])
X.columns = X.columns.str.replace(' ','_').str.replace('[()/\-]','_',regex=True)
dtypes = df.dtypes.to_dict()
num_cols = [c for c in X.columns if dtypes.get(c.replace('_',' '),None) in [np.int64,np.float64]]
X[num_cols] = StandardScaler().fit_transform(X[num_cols])
print('Using train:test = 80:20 split')

# ----- Training & Evaluation -----
results = []
for bal_name, bal in BALANCERS.items():
    X_res, y_res = (bal.fit_resample(X, y) if bal else (X, y))
    X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=42)
    for name, model in MODELS.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average='weighted')
        print(f"-- {name} ({bal_name}) --\nAccuracy: {acc:.3f}, F1 Score: {f1:.3f}")
        print(classification_report(y_test, y_pred, target_names=target_le.classes_))
        cm = confusion_matrix(y_test, y_pred)
        pd.DataFrame(cm, index=target_le.classes_, columns=target_le.classes_).to_csv(
            os.path.join(results_dir, f"cm_{name}_{bal_name}.csv"))
        plt.figure()
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_le.classes_, yticklabels=target_le.classes_)
        plt.title(f"{name} ({bal_name}) Confusion Matrix")
        plt.savefig(os.path.join(plots_dir, f"{name}_{bal_name}_confusion_matrix.png"), bbox_inches='tight')
        plt.show()

        results.append({'Balancer': bal_name, 'Model': name, 'Accuracy': acc, 'F1': f1})

res_df = pd.DataFrame(results)
res_df.to_csv(os.path.join(results_dir, 'model_metrics_no_fe.csv'), index=False)

for metric in ['Accuracy','F1']:
    plt.figure(figsize=(10,6))
    sns.barplot(x='Model', y=metric, hue='Balancer', data=res_df)
    plt.title(f'Model {metric} Comparison')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(os.path.join(plots_dir, f"model_{metric.lower()}_comparison.png"), bbox_inches='tight')
    plt.show()

best_acc = res_df.loc[res_df['Accuracy'].idxmax()]
best_f1 = res_df.loc[res_df['F1'].idxmax()]
print(f"Best Accuracy: {best_acc['Model']} - {best_acc['Accuracy']:.3f} ({best_acc['Balancer']})")
print(f"Best F1 Score: {best_f1['Model']} - {best_f1['F1']:.3f} ({best_f1['Balancer']})")
# Out:
#    Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 0   29  Female     Artist          6.0                           2.7
# 1   46   Other      Nurse          6.2                           5.7
# 2   64    Male      Other          5.0                           3.7
# 3   20  Female  Scientist          5.8                           2.8
# 4   49  Female      Other          8.2                           2.3
#
#    Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 0                       181                                 10     Yes
# 1                       200                                  8     Yes
# 2                       117                                  4      No
# 3                       360                                  6     Yes
# 4                       247                                  4     Yes
#
#   Family History of Anxiety  Stress Level (1-10)  ...  \
# 0                        No                   10  ...
# 1                       Yes                    1  ...
# 2                       Yes                    1  ...
# 3                        No                    4  ...
# 4                        No                    1  ...
#
#    Breathing Rate (breaths/min)  Sweating Level (1-5)  Dizziness Medication  \
# 0                            14                     4         No        Yes
# 1                            23                     2        Yes         No
# 2                            28                     3         No         No
# 3                            17                     3         No         No
# 4                            19                     4        Yes        Yes
#
#   Therapy Sessions (per month)  Recent Major Life Event Diet Quality (1-10)  \
# 0                            3                      Yes                   7
# 1                            2                       No                   8
# 2                            1                      Yes                   1
# 3                            0                       No                   1
# 4                            1                       No                   3
#
#    Anxiety_Level  Stress_Level_numeric  Anxiety_Category
# 0            5.0                    10            Medium
# 1            3.0                     1               Low
# 2            1.0                     1          Very Low
# 3            2.0                     4          Very Low
# 4            1.0                     1          Very Low
#
# [5 rows x 21 columns]
#                  Age  Gender Occupation   Sleep Hours  \
# count   11000.000000   11000      11000  11000.000000
# unique           NaN       3         13           NaN
# top              NaN  Female   Musician           NaN
# freq             NaN    3730        892           NaN
# mean       40.241727     NaN        NaN      6.650691
# std        13.236140     NaN        NaN      1.227509
# min        18.000000     NaN        NaN      2.300000
# 25%        29.000000     NaN        NaN      5.900000
# 50%        40.000000     NaN        NaN      6.700000
# 75%        51.000000     NaN        NaN      7.500000
# max        64.000000     NaN        NaN     11.300000
#
#         Physical Activity (hrs/week)  Caffeine Intake (mg/day)  \
# count                   11000.000000              11000.000000
# unique                           NaN                       NaN
# top                              NaN                       NaN
# freq                             NaN                       NaN
# mean                        2.942136                286.090000
# std                         1.827825                144.813157
# min                         0.000000                  0.000000
# 25%                         1.500000                172.000000
# 50%                         2.800000                273.000000
# 75%                         4.200000                382.000000
# max                        10.100000                599.000000
#
#         Alcohol Consumption (drinks/week) Smoking Family History of Anxiety  \
# count                        11000.000000   11000                     11000
# unique                                NaN       2                         2
# top                                   NaN     Yes                       Yes
# freq                                  NaN    5779                      5847
# mean                             9.701636     NaN                       NaN
# std                              5.689713     NaN                       NaN
# min                              0.000000     NaN                       NaN
# 25%                              5.000000     NaN                       NaN
# 50%                             10.000000     NaN                       NaN
# 75%                             15.000000     NaN                       NaN
# max                             19.000000     NaN                       NaN
#
#         Stress Level (1-10)  ...  Breathing Rate (breaths/min)  \
# count          11000.000000  ...                  11000.000000
# unique                  NaN  ...                           NaN
# top                     NaN  ...                           NaN
# freq                    NaN  ...                           NaN
# mean               5.856364  ...                     20.957545
# std                2.927202  ...                      5.160107
# min                1.000000  ...                     12.000000
# 25%                3.000000  ...                     17.000000
# 50%                6.000000  ...                     21.000000
# 75%                8.000000  ...                     25.000000
# max               10.000000  ...                     29.000000
#
#         Sweating Level (1-5)  Dizziness Medication  \
# count           11000.000000      11000      11000
# unique                   NaN          2          2
# top                      NaN        Yes        Yes
# freq                     NaN       5672       5666
# mean                3.080636        NaN        NaN
# std                 1.398877        NaN        NaN
# min                 1.000000        NaN        NaN
# 25%                 2.000000        NaN        NaN
# 50%                 3.000000        NaN        NaN
# 75%                 4.000000        NaN        NaN
# max                 5.000000        NaN        NaN
#
#        Therapy Sessions (per month)  Recent Major Life Event  \
# count                  11000.000000                    11000
# unique                          NaN                        2
# top                             NaN                      Yes
# freq                            NaN                     5623
# mean                       2.427818                      NaN
# std                        2.183106                      NaN
# min                        0.000000                      NaN
# 25%                        1.000000                      NaN
# 50%                        2.000000                      NaN
# 75%                        4.000000                      NaN
# max                       12.000000                      NaN
#
#        Diet Quality (1-10)  Anxiety_Level  Stress_Level_numeric  \
# count         11000.000000   11000.000000          11000.000000
# unique                 NaN            NaN                   NaN
# top                    NaN            NaN                   NaN
# freq                   NaN            NaN                   NaN
# mean              5.181818       3.929364              5.856364
# std               2.895243       2.122533              2.927202
# min               1.000000       1.000000              1.000000
# 25%               3.000000       2.000000              3.000000
# 50%               5.000000       4.000000              6.000000
# 75%               8.000000       5.000000              8.000000
# max              10.000000      10.000000             10.000000
#
#         Anxiety_Category
# count              11000
# unique                 5
# top                  Low
# freq                4823
# mean                 NaN
# std                  NaN
# min                  NaN
# 25%                  NaN
# 50%                  NaN
# 75%                  NaN
# max                  NaN
#
# [11 rows x 21 columns]
# Using train:test = 80:20 split
# -- Decision Tree (None) --
# Accuracy: 0.505, F1 Score: 0.505
#               precision    recall  f1-score   support
#
#         High       0.33      0.36      0.34       103
#          Low       0.52      0.53      0.53       946
#       Medium       0.43      0.42      0.43       442
#    Very High       0.66      0.64      0.65       140
#     Very Low       0.53      0.52      0.52       569
#
#     accuracy                           0.50      2200
#    macro avg       0.49      0.49      0.49      2200
# weighted avg       0.51      0.50      0.50      2200
# -- Random Forest (None) --
# Accuracy: 0.595, F1 Score: 0.579
#               precision    recall  f1-score   support
#
#         High       0.21      0.04      0.07       103
#          Low       0.57      0.70      0.63       946
#       Medium       0.56      0.44      0.49       442
#    Very High       0.63      0.89      0.74       140
#     Very Low       0.67      0.57      0.62       569
#
#     accuracy                           0.59      2200
#    macro avg       0.53      0.53      0.51      2200
# weighted avg       0.58      0.59      0.58      2200
# -- KNN (None) --
# Accuracy: 0.467, F1 Score: 0.441
#               precision    recall  f1-score   support
#
#         High       0.28      0.23      0.25       103
#          Low       0.49      0.69      0.57       946
#       Medium       0.35      0.21      0.27       442
#    Very High       0.55      0.66      0.60       140
#     Very Low       0.48      0.28      0.35       569
#
#     accuracy                           0.47      2200
#    macro avg       0.43      0.42      0.41      2200
# weighted avg       0.45      0.47      0.44      2200
# -- Logistic Regression (None) --
# Accuracy: 0.589, F1 Score: 0.576
#               precision    recall  f1-score   support
#
#         High       0.24      0.07      0.11       103
#          Low       0.57      0.69      0.63       946
#       Medium       0.52      0.41      0.46       442
#    Very High       0.59      0.85      0.70       140
#     Very Low       0.69      0.59      0.64       569
#
#     accuracy                           0.59      2200
#    macro avg       0.52      0.52      0.51      2200
# weighted avg       0.58      0.59      0.58      2200
# -- Gaussian NB (None) --
# Accuracy: 0.620, F1 Score: 0.606
#               precision    recall  f1-score   support
#
#         High       0.08      0.02      0.03       103
#          Low       0.61      0.66      0.64       946
#       Medium       0.58      0.53      0.55       442
#    Very High       0.64      0.94      0.76       140
#     Very Low       0.67      0.65      0.66       569
#
#     accuracy                           0.62      2200
#    macro avg       0.52      0.56      0.53      2200
# weighted avg       0.60      0.62      0.61      2200
# -- SVM (None) --
# Accuracy: 0.434, F1 Score: 0.266
#               precision    recall  f1-score   support
#
#         High       0.00      0.00      0.00       103
#          Low       0.43      1.00      0.60       946
#       Medium       0.00      0.00      0.00       442
#    Very High       0.62      0.06      0.10       140
#     Very Low       0.00      0.00      0.00       569
#
#     accuracy                           0.43      2200
#    macro avg       0.21      0.21      0.14      2200
# weighted avg       0.23      0.43      0.27      2200
# -- ANN (None) --
# Accuracy: 0.585, F1 Score: 0.571
#               precision    recall  f1-score   support
#
#         High       0.23      0.03      0.05       103
#          Low       0.61      0.52      0.56       946
#       Medium       0.49      0.65      0.56       442
#    Very High       0.63      0.90      0.74       140
#     Very Low       0.63      0.67      0.65       569
#
#     accuracy                           0.58      2200
#    macro avg       0.52      0.55      0.51      2200
# weighted avg       0.58      0.58      0.57      2200
# -- CatBoost (None) --
# Accuracy: 0.591, F1 Score: 0.581
#               precision    recall  f1-score   support
#
#         High       0.24      0.08      0.12       103
#          Low       0.58      0.66      0.62       946
#       Medium       0.54      0.49      0.51       442
#    Very High       0.63      0.84      0.72       140
#     Very Low       0.67      0.59      0.63       569
#
#     accuracy                           0.59      2200
#    macro avg       0.53      0.53      0.52      2200
# weighted avg       0.58      0.59      0.58      2200
# -- XGBoost (None) --
# Accuracy: 0.580, F1 Score: 0.573
#               precision    recall  f1-score   support
#
#         High       0.33      0.16      0.21       103
#          Low       0.57      0.66      0.61       946
#       Medium       0.53      0.47      0.50       442
#    Very High       0.64      0.76      0.69       140
#     Very Low       0.65      0.57      0.60       569
#
#     accuracy                           0.58      2200
#    macro avg       0.54      0.52      0.52      2200
# weighted avg       0.57      0.58      0.57      2200
# -- LightGBM (None) --
# Accuracy: 0.585, F1 Score: 0.577
#               precision    recall  f1-score   support
#
#         High       0.32      0.15      0.20       103
#          Low       0.57      0.67      0.62       946
#       Medium       0.53      0.46      0.49       442
#    Very High       0.64      0.78      0.70       140
#     Very Low       0.67      0.57      0.62       569
#
#     accuracy                           0.58      2200
#    macro avg       0.55      0.53      0.53      2200
# weighted avg       0.58      0.58      0.58      2200
# -- Decision Tree (ROS) --
# Accuracy: 0.837, F1 Score: 0.830
#               precision    recall  f1-score   support
#
#         High       0.98      1.00      0.99       987
#          Low       0.66      0.49      0.56       961
#       Medium       0.77      0.87      0.82       949
#    Very High       1.00      1.00      1.00       918
#     Very Low       0.76      0.83      0.79      1008
#
#     accuracy                           0.84      4823
#    macro avg       0.83      0.84      0.83      4823
# weighted avg       0.83      0.84      0.83      4823
# -- Random Forest (ROS) --
# Accuracy: 0.874, F1 Score: 0.870
#               precision    recall  f1-score   support
#
#         High       1.00      1.00      1.00       987
#          Low       0.74      0.59      0.65       961
#       Medium       0.82      0.92      0.87       949
#    Very High       1.00      1.00      1.00       918
#     Very Low       0.81      0.87      0.84      1008
#
#     accuracy                           0.87      4823
#    macro avg       0.87      0.87      0.87      4823
# weighted avg       0.87      0.87      0.87      4823
# -- KNN (ROS) --
# Accuracy: 0.697, F1 Score: 0.689
#               precision    recall  f1-score   support
#
#         High       0.88      0.99      0.94       987
#          Low       0.42      0.39      0.40       961
#       Medium       0.57      0.59      0.58       949
#    Very High       0.91      0.98      0.95       918
#     Very Low       0.64      0.55      0.59      1008
#
#     accuracy                           0.70      4823
#    macro avg       0.69      0.70      0.69      4823
# weighted avg       0.68      0.70      0.69      4823
# -- Logistic Regression (ROS) --
# Accuracy: 0.550, F1 Score: 0.537
#               precision    recall  f1-score   support
#
#         High       0.42      0.28      0.34       987
#          Low       0.46      0.39      0.42       961
#       Medium       0.54      0.59      0.56       949
#    Very High       0.55      0.75      0.64       918
#     Very Low       0.72      0.74      0.73      1008
#
#     accuracy                           0.55      4823
#    macro avg       0.54      0.55      0.54      4823
# weighted avg       0.54      0.55      0.54      4823
# -- Gaussian NB (ROS) --
# Accuracy: 0.568, F1 Score: 0.511
#               precision    recall  f1-score   support
#
#         High       0.34      0.07      0.11       987
#          Low       0.50      0.31      0.38       961
#       Medium       0.54      0.76      0.63       949
#    Very High       0.55      0.92      0.69       918
#     Very Low       0.70      0.79      0.74      1008
#
#     accuracy                           0.57      4823
#    macro avg       0.53      0.57      0.51      4823
# weighted avg       0.53      0.57      0.51      4823
# -- SVM (ROS) --
# Accuracy: 0.481, F1 Score: 0.417
#               precision    recall  f1-score   support
#
#         High       0.38      0.05      0.09       987
#          Low       0.30      0.18      0.22       961
#       Medium       0.46      0.52      0.49       949
#    Very High       0.48      0.96      0.64       918
#     Very Low       0.60      0.71      0.65      1008
#
#     accuracy                           0.48      4823
#    macro avg       0.44      0.49      0.42      4823
# weighted avg       0.45      0.48      0.42      4823
# -- ANN (ROS) --
# Accuracy: 0.568, F1 Score: 0.512
#               precision    recall  f1-score   support
#
#         High       0.52      0.08      0.14       987
#          Low       0.48      0.30      0.37       961
#       Medium       0.50      0.82      0.62       949
#    Very High       0.57      0.95      0.71       918
#     Very Low       0.75      0.71      0.73      1008
#
#     accuracy                           0.57      4823
#    macro avg       0.56      0.57      0.51      4823
# weighted avg       0.56      0.57      0.51      4823
# -- CatBoost (ROS) --
# Accuracy: 0.840, F1 Score: 0.836
#               precision    recall  f1-score   support
#
#         High       1.00      0.98      0.99       987
#          Low       0.66      0.52      0.58       961
#       Medium       0.77      0.87      0.81       949
#    Very High       0.98      1.00      0.99       918
#     Very Low       0.78      0.83      0.80      1008
#
#     accuracy                           0.84      4823
#    macro avg       0.84      0.84      0.84      4823
# weighted avg       0.84      0.84      0.84      4823
# -- XGBoost (ROS) --
# Accuracy: 0.853, F1 Score: 0.848
#               precision    recall  f1-score   support
#
#         High       1.00      1.00      1.00       987
#          Low       0.68      0.53      0.60       961
#       Medium       0.77      0.89      0.83       949
#    Very High       1.00      1.00      1.00       918
#     Very Low       0.79      0.85      0.82      1008
#
#     accuracy                           0.85      4823
#    macro avg       0.85      0.85      0.85      4823
# weighted avg       0.85      0.85      0.85      4823
# -- LightGBM (ROS) --
# Accuracy: 0.834, F1 Score: 0.829
#               precision    recall  f1-score   support
#
#         High       0.99      1.00      1.00       987
#          Low       0.64      0.49      0.56       961
#       Medium       0.75      0.84      0.79       949
#    Very High       1.00      1.00      1.00       918
#     Very Low       0.77      0.84      0.80      1008
#
#     accuracy                           0.83      4823
#    macro avg       0.83      0.83      0.83      4823
# weighted avg       0.83      0.83      0.83      4823
# -- Decision Tree (SMOTE) --
# Accuracy: 0.688, F1 Score: 0.688
#               precision    recall  f1-score   support
#
#         High       0.81      0.84      0.82       987
#          Low       0.46      0.46      0.46       961
#       Medium       0.59      0.59      0.59       949
#    Very High       0.89      0.89      0.89       918
#     Very Low       0.69      0.66      0.68      1008
#
#     accuracy                           0.69      4823
#    macro avg       0.69      0.69      0.69      4823
# weighted avg       0.69      0.69      0.69      4823
# -- Random Forest (SMOTE) --
# Accuracy: 0.809, F1 Score: 0.806
#               precision    recall  f1-score   support
#
#         High       0.99      0.93      0.96       987
#          Low       0.62      0.51      0.56       961
#       Medium       0.71      0.82      0.76       949
#    Very High       0.96      0.99      0.98       918
#     Very Low       0.76      0.81      0.78      1008
#
#     accuracy                           0.81      4823
#    macro avg       0.81      0.81      0.81      4823
# weighted avg       0.81      0.81      0.81      4823
# -- KNN (SMOTE) --
# Accuracy: 0.743, F1 Score: 0.730
#               precision    recall  f1-score   support
#
#         High       0.83      0.98      0.90       987
#          Low       0.49      0.35      0.40       961
#       Medium       0.65      0.74      0.69       949
#    Very High       0.92      0.99      0.96       918
#     Very Low       0.73      0.67      0.70      1008
#
#     accuracy                           0.74      4823
#    macro avg       0.73      0.74      0.73      4823
# weighted avg       0.73      0.74      0.73      4823
# -- Logistic Regression (SMOTE) --
# Accuracy: 0.571, F1 Score: 0.560
#               precision    recall  f1-score   support
#
#         High       0.43      0.30      0.36       987
#          Low       0.50      0.43      0.47       961
#       Medium       0.56      0.63      0.59       949
#    Very High       0.55      0.72      0.63       918
#     Very Low       0.74      0.77      0.76      1008
#
#     accuracy                           0.57      4823
#    macro avg       0.56      0.57      0.56      4823
# weighted avg       0.56      0.57      0.56      4823
# -- Gaussian NB (SMOTE) --
# Accuracy: 0.592, F1 Score: 0.547
#               precision    recall  f1-score   support
#
#         High       0.47      0.11      0.17       987
#          Low       0.54      0.43      0.48       961
#       Medium       0.55      0.73      0.63       949
#    Very High       0.56      0.93      0.70       918
#     Very Low       0.74      0.78      0.76      1008
#
#     accuracy                           0.59      4823
#    macro avg       0.57      0.60      0.55      4823
# weighted avg       0.57      0.59      0.55      4823
# -- SVM (SMOTE) --
# Accuracy: 0.486, F1 Score: 0.425
#               precision    recall  f1-score   support
#
#         High       0.41      0.05      0.09       987
#          Low       0.36      0.21      0.27       961
#       Medium       0.47      0.53      0.50       949
#    Very High       0.46      0.96      0.62       918
#     Very Low       0.61      0.71      0.66      1008
#
#     accuracy                           0.49      4823
#    macro avg       0.46      0.49      0.43      4823
# weighted avg       0.46      0.49      0.43      4823
# -- ANN (SMOTE) --
# Accuracy: 0.564, F1 Score: 0.515
#               precision    recall  f1-score   support
#
#         High       0.46      0.86      0.60       987
#          Low       0.55      0.37      0.44       961
#       Medium       0.60      0.62      0.61       949
#    Very High       0.76      0.07      0.13       918
#     Very Low       0.68      0.85      0.76      1008
#
#     accuracy                           0.56      4823
#    macro avg       0.61      0.56      0.51      4823
# weighted avg       0.61      0.56      0.51      4823
# -- CatBoost (SMOTE) --
# Accuracy: 0.791, F1 Score: 0.790
#               precision    recall  f1-score   support
#
#         High       0.94      0.85      0.90       987
#          Low       0.61      0.57      0.59       961
#       Medium       0.74      0.79      0.76       949
#    Very High       0.89      0.96      0.93       918
#     Very Low       0.78      0.78      0.78      1008
#
#     accuracy                           0.79      4823
#    macro avg       0.79      0.79      0.79      4823
# weighted avg       0.79      0.79      0.79      4823
# -- XGBoost (SMOTE) --
# Accuracy: 0.791, F1 Score: 0.790
#               precision    recall  f1-score   support
#
#         High       0.94      0.88      0.91       987
#          Low       0.60      0.57      0.58       961
#       Medium       0.74      0.77      0.75       949
#    Very High       0.91      0.96      0.93       918
#     Very Low       0.77      0.77      0.77      1008
#
#     accuracy                           0.79      4823
#    macro avg       0.79      0.79      0.79      4823
# weighted avg       0.79      0.79      0.79      4823
# -- LightGBM (SMOTE) --
# Accuracy: 0.788, F1 Score: 0.788
#               precision    recall  f1-score   support
#
#         High       0.94      0.86      0.90       987
#          Low       0.61      0.59      0.60       961
#       Medium       0.72      0.76      0.74       949
#    Very High       0.91      0.96      0.94       918
#     Very Low       0.77      0.78      0.78      1008
#
#     accuracy                           0.79      4823
#    macro avg       0.79      0.79      0.79      4823
# weighted avg       0.79      0.79      0.79      4823
# Best Accuracy: Random Forest - 0.874 (ROS)
# Best F1 Score: Random Forest - 0.870 (ROS)
